# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
from os.path import basename
import requests
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver  = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 91.0.4472
# [WDM] - Get LATEST driver version for 91.0.4472
#
#
# [WDM] - Driver [/Users/josephgallart/.wdm/drivers/chromedriver/mac64/91.0.4472.101/chromedriver] found in cache

# %%
driver.get("http://www.booking.es")

# %%
time.sleep(5)

# %%
driver.find_element_by_id("onetrust-accept-btn-handler").click()

# %%
time.sleep(5)

# %%
lista_botones=driver.find_elements_by_class_name("bui-button.bui-button--secondary.js-header-login-link")

# %%
for i in lista_botones:
    print(i.text)
# Out:
# Hazte una cuenta
# Inicia sesión

# %%
lista_botones[1].click()

# %%
time.sleep(5)

# %%
driver.find_element_by_id("username").send_keys("josephquai@gmail.com")

# %%
driver.find_elements_by_class_name("bui-button.bui-button--large.bui-button--wide")[0].click()

# %%
time.sleep(5)

# %%
driver.find_elements_by_id("password")[0].send_keys("Joseph1234")

# %%
lista_botones=driver.find_elements_by_class_name("bui-button.bui-button--large.bui-button--wide")

# %%
for i in lista_botones:
    print(i.text)
# Out:
# Iniciar sesión
# Iniciar sesión con enlace de verificación

# %%
lista_botones[0].click()

# %%
time.sleep(5)

# %%
lista_botones=driver.find_elements_by_class_name("sb-destination__clear.-visible")

# %%
lista_botones[0].click()

# %%
driver.find_elements_by_id("ss")[0].send_keys("Granada")

# %%
lista_desplegable=driver.find_elements_by_class_name("c-autocomplete__item.sb-autocomplete__item.sb-autocomplete__item-with_photo.sb-autocomplete__item__item--elipsis.sb-autocomplete__item--icon_revamp.sb-autocomplete__item--city")

# %%
for i in lista_desplegable:
    print(i.text)
# Out:
# Granada
# Andalucía, España
# Almuñécar
# Andalucía, España
