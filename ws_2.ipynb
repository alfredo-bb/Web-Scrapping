# %%
# !pip install selenium

# %%
# !pip install webdriver_manager

# %%
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver  = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - ====== WebDriver manager ======
#
#
# [WDM] - Current google-chrome version is 91.0.4472
# [WDM] - Get LATEST driver version for 91.0.4472
# [WDM] - Driver [/Users/josephgallart/.wdm/drivers/chromedriver/mac64/91.0.4472.101/chromedriver] found in cache

# %%
driver.get("http://www.google.com")

# %%
google_click=driver.find_element_by_id("L2AGLb")

# %%
google_click.click()

# %%
driver.find_element_by_name("q")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e39a9e2db4ca03790e206521d2789da2", element="8480ff6b-96bb-48a4-b227-295e62d44cd1")>

# %%
driver.find_element_by_class_name("pR49Ae.gsfi")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e39a9e2db4ca03790e206521d2789da2", element="7f469474-70f8-40af-80d0-2fa8d2967c10")>

# %%
search_box=driver.find_elements_by_name("q")[0]

# %%
search_box.send_keys("Eurocopa")

# %%
search_box.submit()

# %%
driver.find_elements_by_class_name("KAIX8d")[4].click()
